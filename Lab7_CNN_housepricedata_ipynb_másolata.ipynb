# %% [markdown]
# <a href="https://colab.research.google.com/github/Actulus/MI/blob/main/Lab7_CNN_housepricedata_ipynb_m%C3%A1solata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A téma ismertetése:
#
# Ebben a bejegyzésben azt fogjuk megvizsgálni, hogyan használjuk a Keras nevű csomagot az első neurális hálózatunk létrehozásához, hogy megjósoljuk, hogy a lakásárak a mediánérték felett vagy alatt vannak-e. Konkrétan végigmegyünk a teljes Deep Learning pipeline-on, a következők szerint:
#
# *   Az adatok feltárása és feldolgozása
# *   Neurális hálózatunk építése és képzése
# *   A veszteség és a pontosság vizualizálása
# *   Szabályozás hozzáadása a neurális hálózatunkhoz
#
# Az adatok feltárása és feldolgozása
# Mielőtt bármilyen ML-algoritmust kódolnánk, az első dolog, amit tennünk kell, hogy az adatainkat olyan formátumba hozzuk, amelyet az algoritmus szeretne. Különösen a következőkre van szükségünk:
# *   Beolvasni a CSV (vesszővel elválasztott értékek) fájlt, és tömbökké alakítani őket. A tömbök olyan adatformátumot jelentenek, amelyet az algoritmusunk fel tud dolgozni.
# *   Az adathalmazunkat fel kell osztanunk a bemeneti jellemzőkre (amelyeket x-nek nevezünk) és a címkékre (amelyeket y-nak nevezünk).
# *   Méretezzük az adatokat (ezt nevezzük normalizálásnak), hogy a bemeneti jellemzők hasonló nagyságrendűek legyenek.
# *   Osszuk fel az adathalmazunkat a gyakorlóhalmazra, a validációs halmazra és a teszthalmazra.
#
# # Adathalmaz:
#
# A ma használt adathalmaz a Zillow Home Value Prediction Kaggle verseny adataiból származik. Csökkentettük a bemeneti jellemzők számát, és a feladatot úgy módosítottuk, hogy megjósoljuk, hogy a ház ára a mediánérték felett vagy alatt van-e.

# %%
import pandas as pd

# %% [markdown]
# Ez csak azt jelenti, hogy ha a 'pandas' csomagban lévő kódra akarok hivatkozni, akkor a pd névvel fogok rá hivatkozni. Ezután beolvassuk a CSV fájlt a következő kódsor futtatásával:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/MI/lab6/housepricedata_1461.csv')

# %% [markdown]
# Ez a kódsor azt jelenti, hogy beolvassuk a 'housepricedata.csv' csv fájlt (amelynek ugyanabban a könyvtárban kell lennie, mint a notebookunknak), és a 'df' változóban tároljuk. Ha meg akarjuk tudni, hogy mi van a df-ben, egyszerűen írjuk be a df-et a szürke mezőbe, és nyomjuk meg az Alt-Enter billentyűt:
# A notebookodnak valahogy így kell kinéznie:

# %%
df
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0                3             8           0         548                 1
# 1                3             6           1         460                 1
# 2                3             6           1         608                 1
# 3                3             7           1         642                 0
# 4                4             9           1         836                 1
# ...            ...           ...         ...         ...               ...
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0
#
# [1460 rows x 11 columns]

# %% [markdown]
# Itt egy kicsit felfedezheti az adatokat. A bemeneti jellemzőink az első tíz oszlopban vannak:
# *   A telek területe (négyzetméterben)
# *   Általános minőség (1-től 10-ig terjedő skála)
# *   Általános állapot (1-től 10-ig terjedő skála)
# *   Teljes pincefelület (négyzetméterben)
# *   Teljes fürdőszobák száma
# *   Félfürdőszobák száma
# *   Földszint feletti hálószobák száma
# *   Földszint feletti szobák száma összesen
# *   Kandallók száma
# *   Garázs területe (négyzetméterben)
#
# Az utolsó oszlopban van az a tulajdonság, amelyet szeretnénk megjósolni:
# *   A ház ára a medián felett van-e vagy sem? (1 az igen és 0 a nem)

# %% [markdown]
# Most, hogy láttuk, hogyan néznek ki az adataink, szeretnénk azokat tömbökké alakítani, hogy a gépünk feldolgozhassa őket:

# %%
dataset = df.values

# %% [markdown]
# Az adatkeretünk tömbté alakításához egyszerűen tároljuk a df értékeit (a df.values elérésével) a 'dataset' változóban. Ahhoz, hogy megnézzük, mi van ebben a 'dataset' változóban, egyszerűen írjuk be a 'dataset' szót a notebook szürke dobozába, és futtassuk le a cellát (Alt-Enter):

# %% [markdown]
# Amint láthatod, most minden egy tömbben van tárolva:

# %%
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]])

# %% [markdown]
# Most az adathalmazunkat felosztjuk bemeneti jellemzőkre (X) és a megjósolni kívánt jellemzőre (Y). Ehhez a felosztáshoz egyszerűen hozzárendeljük a tömbünk első 10 oszlopát egy X nevű változóhoz, a tömbünk utolsó oszlopát pedig egy Y nevű változóhoz:

# %%
X = dataset[:,0:10]

# %% [markdown]
# Ez egy kicsit furcsának tűnhet, de hadd magyarázzam el, mi van a szögletes zárójelek között. Minden, ami a vessző előtt van, a tömb soraira utal, és minden, ami a vessző után van, a tömbök oszlopaira.
#
# Mivel nem osztjuk fel a sorokat, ezért a vessző elé ':'-t teszünk. Ez azt jelenti, hogy az adatkészlet összes sorát vesszük és X-be tesszük.
#
# Az első 10 oszlopot szeretnénk kivenni, ezért a vessző utáni '0:10' azt jelenti, hogy vegyük a 0-9 oszlopokat és tegyük az X-be (a 10. oszlopot nem vesszük bele). Az oszlopaink a 0 indexszel kezdődnek, így az első 10 oszlop valójában a 0-9 oszlopok.
#
# Ezután a tömbünk utolsó oszlopát az Y-hoz rendeljük:

# %%
Y = dataset[:,10]

# %% [markdown]
# Oké, most már felosztottuk az adathalmazunkat bemeneti jellemzőkre (X) és annak a címkére, amit meg akarunk jósolni (Y).
#
# A feldolgozásunk következő lépése, hogy megbizonyosodjunk arról, hogy a bemeneti jellemzők skálája hasonló. Jelenleg az olyan jellemzők, mint a telek területe, ezres nagyságrendűek, az általános minőségre vonatkozó pontszám 1 és 10 között mozog, a kandallók száma pedig általában 0, 1 vagy 2 értékű.

# %% [markdown]
# Ez megnehezíti a neurális hálózat inicializálását, ami gyakorlati problémákat okoz. Az adatok skálázásának egyik módja a scikit-learn egy meglévő csomagjának használata.
#
# Először is importálnunk kell a kódot, amelyet használni szeretnénk:

# %%
from sklearn import preprocessing

# %% [markdown]
# Ez azt mondja, hogy a sklearn csomagon belül a 'preprocessing' kódot szeretném használni. Ezután egy min-max scaler nevű függvényt használunk, amely úgy méretezi az adathalmazt, hogy az összes bemeneti jellemző 0 és 1 között legyen:

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %% [markdown]
# Megjegyzendő, hogy szándékosan választottuk a 0 és 1 értékeket, hogy segítsük a neurális hálózatunk képzését. Nem fogjuk végigvenni az elméletet, ami emögött áll. Most a skálázott adathalmazunkat az 'X_scale' tömbben tároljuk. Ha látni szeretné, hogyan néz ki az 'X_scale', egyszerűen futtassa a cellát:
# A Jupyter notebookodnak most már valahogy így kell kinéznie:

# %%
X_scale
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %% [markdown]
# Most az adatok feldolgozásának utolsó lépésénél tartunk, ami az adathalmazunk felosztása egy képzési halmazra, egy validálási halmazra és egy teszthalmazra.
#
# A scikit-learn "train_test_split" nevű kódját fogjuk használni, amely, ahogy a neve is mutatja, az adathalmazunkat egy gyakorló és egy tesztkészletre osztja. Először is importáljuk a szükséges kódot:

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Ezután ossza fel az adatállományt a következőképpen:
# Ez azt mondja a scikit-learnnek, hogy a val_and_test mérete a teljes adathalmaz 30%-a lesz. A kód a felosztott adatokat az egyenlőségjel bal oldalán lévő első négy változóba fogja tárolni, ahogy a változónevek is sugallják.

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %% [markdown]
# Sajnos ez a funkció csak abban segít, hogy az adathalmazunkat kettéosszuk. Mivel külön validációs és külön tesztkészletet szeretnénk, ugyanazzal a függvénnyel újra elvégezhetjük a felosztást a val_és_tesztkészleten:

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %% [markdown]
# A fenti kód a val_és_test méretét egyenlően osztja fel a validációs és a tesztkészletre.

# %% [markdown]
# Összefoglalva, most már összesen hat változóval rendelkezünk az általunk használt adatkészletekhez:
# *   X_train (10 bemeneti jellemző, a teljes adathalmaz 70%-a)
# *   X_val (10 bemeneti jellemző, a teljes adathalmaz 15%-a)
# *   X_test (10 bemeneti jellemző, a teljes adathalmaz 15%-a)
# *   Y_train (1 címke, a teljes adathalmaz 70%-a)
# *   Y_val (1 címke, a teljes adatállomány 15%-a)
# *   Y_test (1 címke, a teljes adatállomány 15%-a)
#
# Ha látni szeretné, hogy a tömbök milyen alakúak az egyes tömbök (azaz milyen dimenziójúak), egyszerűen futtassa le a print esetet.
# Így kell kinéznie a Jupyter notebooknak:

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %% [markdown]
# Mint látható, a gyakorlóhalmaz 1022 adatpontot tartalmaz, míg a validációs és teszthalmaz egyenként 219 adatpontot. Az X változók 10 bemeneti jellemzővel rendelkeznek, míg az Y változóknak csak egy jellemzőt kell megjósolniuk.
#
# És most végre készen vannak az adataink! Júúúhéééé!

# %% [markdown]
# Összefoglaló: Az adatok feldolgozása során:
# *   Beolvastuk a CSV (vesszővel elválasztott értékek) fájlt, és tömbökké alakítottuk őket.
# *   Az adathalmazunkat felosztottuk a bemeneti jellemzők és a címke között.
# *   Méreteztük az adatokat úgy, hogy a bemeneti jellemzők hasonló nagyságrendűek legyenek.
# *   Osszuk fel az adathalmazunkat a gyakorlóhalmazra, a validációs halmazra és a teszthalmazra.

# %% [markdown]
# # Az első neurális hálózatunk építése és kiképzése
# Az Intuitív mélytanulás, azt mondtuk, hogy a gépi tanulás két lépésből áll. Az első lépés egy sablon (egy architektúra) megadása, a második lépés pedig a legjobb számok megtalálása az adatokból, hogy kitöltsük ezt a sablont. A kódunk innentől kezdve szintén ezt a két lépést fogja követni.
#
# # Első lépés: Az architektúra beállítása
# Az első teendőnk az architektúra beállítása. Először is gondoljuk át, hogy milyen neurális hálózati architektúrát szeretnénk. Tegyük fel, hogy ezt a neurális hálózatot szeretnénk:
#
# ![Neural Network model.png](data:image/png;base64,...)

# %% [markdown]
# Ezek a rétegek:
# *   Rejtett réteg 1: 32 neuron, ReLU-aktiválás
# *   Rejtett réteg 2: 32 neuron, ReLU aktiválás
# *   Kimeneti réteg: 1 neuron, Sigmoid aktiválás
#
# Most ezt az architektúrát kell leírnunk a Keras számára. A szekvenciális modellt fogjuk használni, ami azt jelenti, hogy csupán a fenti rétegeket kell leírnunk egymás után.

# %% [markdown]
# Először is importáljuk a szükséges kódot a Kerasból:

# %%
#FNW
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# Ezután ezt a Keras szekvenciális modellünkben így adjuk meg:

# %% [markdown]
# És csak így, a fenti kódrészlet meghatározta az architektúránkat! A fenti kód így értelmezhető:
#
# model = Sequential([ ... ])
#
# Ez azt mondja, hogy a modellünket a 'model' változóban fogjuk tárolni, és a szögletes zárójelek között szekvenciálisan (rétegről rétegre) fogjuk leírni.
#
# Dense(32, activation='relu', input_shape=(10,)),
#
# Az első rétegünk egy sűrű réteg, 32 neuronnal, ReLU aktiválással, és a bemeneti alak 10, mivel 10 bemeneti jellemzőnk van. Megjegyezzük, hogy a "Dense" a teljesen összekapcsolt rétegre utal, amit használni fogunk.
#
# Dense(32, activation='relu'),
#
# A második rétegünk szintén egy sűrű réteg 32 neuronnal, ReLU aktiválással. Megjegyezzük, hogy nem kell leírnunk a bemeneti alakot, mivel a Keras képes következtetni az első rétegünk kimenetéből.
#
# Dense(1, activation='sigmoid'),
#
#
# A harmadik rétegünk egy sűrű réteg 1 neuronnal, szigmoid aktiválással.
#
# És máris megírtuk a modellünk architektúráját (sablon) kódban!

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %% [markdown]
# # Második lépés: A legjobb számok kitöltése
# Most, hogy megadtuk az architektúránkat, meg kell találnunk a legjobb számokat hozzá. Mielőtt elkezdenénk a képzést, konfigurálnunk kell a modellt az alábbiak szerint.
#
# Megadjuk neki, hogy melyik algoritmust szeretnénk használni az optimalizáláshoz
# Megmondjuk, hogy milyen veszteségfüggvényt használjon.
#
# Megmondjuk, hogy a veszteségfüggvényen kívül milyen más mérőszámokat szeretnénk követni.
#
# A modell konfigurálásához ezekkel a beállításokkal meg kell hívnunk a model.compile függvényt, így:

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# A következő beállításokat a zárójelek közé tesszük a model.compile után:
# *   optimizer='sgd' - Az 'sgd' a sztochasztikus gradiens ereszkedésre utal
# *   loss='binary_crossentropy' - Az 1 vagy 0 értékű kimenetekre vonatkozó veszteségfüggvényt bináris keresztentrópiának nevezzük.
# *   metrics=['accuracy'] -Végül a veszteségfüggvényen felül a pontosságot is nyomon akarjuk követni.
#
# Az adatokon való képzés meglehetősen egyszerű, és egyetlen sor kódot kell írnunk:

# %% [markdown]
# adatokhoz illesztjük. Meg kell adnunk, hogy milyen adatokra képezünk, ezek az X_train és Y_train adatok. Ezután megadjuk a minitételünk méretét, és azt, hogy mennyi ideig szeretnénk edzeni (epochák). Végül megadjuk, hogy mik a validációs adataink, hogy a modell minden egyes ponton megmondja, hogyan teljesítünk a validációs adatokon. Ez a függvény egy előzményt ad ki, amelyet a hist változó alatt mentünk el. Ezt a változót kicsit később fogjuk használni, amikor a vizualizációra térünk.
#
# Most futtasd a cellát, és nézd, ahogy edz! A Jupyter notebookodnak így kell kinéznie:

# %%
hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))

# loss accuracy - tanulasra utal
# val_loss - validaciora utal
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 10ms/step - loss: 0.7108 - accuracy: 0.3337 - val_loss: 0.7016 - val_accuracy: 0.3790
# Epoch 2/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7020 - accuracy: 0.3728 - val_loss: 0.6945 - val_accuracy: 0.4521
# Epoch 3/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6956 - accuracy: 0.4452 - val_loss: 0.6887 - val_accuracy: 0.4977
# Epoch 4/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.4834 - val_loss: 0.6833 - val_accuracy: 0.5160
# Epoch 5/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6849 - accuracy: 0.4980 - val_loss: 0.6784 - val_accuracy: 0.5297
# Epoch 6/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.5294 - val_loss: 0.6742 - val_accuracy: 0.5479
# Epoch 7/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6763 - accuracy: 0.5744 - val_loss: 0.6701 - val_accuracy: 0.6210
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6725 - accuracy: 0.6585 - val_loss: 0.6661 - val_accuracy: 0.7260
# Epoch 9/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6688 - accuracy: 0.7211 - val_loss: 0.6621 - val_accuracy: 0.7534
# Epoch 10/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6651 - accuracy: 0.7339 - val_loss: 0.6581 - val_accuracy: 0.7717
# Epoch 11/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6612 - accuracy: 0.7515 - val_loss: 0.6540 - val_accuracy: 0.7763
# Epoch 12/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6574 - accuracy: 0.7661 - val_loss: 0.6498 - val_accuracy: 0.7854
# Epoch 13/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6534 - accuracy: 0.7671 - val_loss: 0.6454 - val_accuracy: 0.8128
# Epoch 14/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6492 - accuracy: 0.7779 - val_loss: 0.6409 - val_accuracy: 0.8174
# Epoch 15/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6449 - accuracy: 0.8131 - val_loss: 0.6361 - val_accuracy: 0.8174
# Epoch 16/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6403 - accuracy: 0.8121 - val_loss: 0.6311 - val_accuracy: 0.8265
# Epoch 17/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6356 - accuracy: 0.8200 - val_loss: 0.6257 - val_accuracy: 0.8265
# Epoch 18/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6307 - accuracy: 0.8170 - val_loss: 0.6201 - val_accuracy: 0.8356
# Epoch 19/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6251 - accuracy: 0.8278 - val_loss: 0.6139 - val_accuracy: 0.8356
# Epoch 20/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6190 - accuracy: 0.8346 - val_loss: 0.6072 - val_accuracy: 0.8356
# Epoch 21/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6127 - accuracy: 0.8327 - val_loss: 0.6001 - val_accuracy: 0.8493
# Epoch 22/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6060 - accuracy: 0.8386 - val_loss: 0.5928 - val_accuracy: 0.8493
# Epoch 23/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5990 - accuracy: 0.8415 - val_loss: 0.5853 - val_accuracy: 0.8493
# Epoch 24/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5920 - accuracy: 0.8425 - val_loss: 0.5776 - val_accuracy: 0.8493
# Epoch 25/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5846 - accuracy: 0.8454 - val_loss: 0.5697 - val_accuracy: 0.8493
# Epoch 26/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5768 - accuracy: 0.8454 - val_loss: 0.5616 - val_accuracy: 0.8539
# Epoch 27/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5689 - accuracy: 0.8493 - val_loss: 0.5531 - val_accuracy: 0.8539
# Epoch 28/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5605 - accuracy: 0.8483 - val_loss: 0.5443 - val_accuracy: 0.8539
# Epoch 29/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5520 - accuracy: 0.8503 - val_loss: 0.5354 - val_accuracy: 0.8584
# Epoch 30/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5433 - accuracy: 0.8483 - val_loss: 0.5262 - val_accuracy: 0.8676
# Epoch 31/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5341 - accuracy: 0.8552 - val_loss: 0.5170 - val_accuracy: 0.8767
# Epoch 32/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5253 - accuracy: 0.8552 - val_loss: 0.5075 - val_accuracy: 0.8767
# Epoch 33/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5155 - accuracy: 0.8581 - val_loss: 0.4978 - val_accuracy: 0.8858
# Epoch 34/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5061 - accuracy: 0.8562 - val_loss: 0.4882 - val_accuracy: 0.8813
# Epoch 35/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4964 - accuracy: 0.8552 - val_loss: 0.4786 - val_accuracy: 0.8813
# Epoch 36/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4870 - accuracy: 0.8571 - val_loss: 0.4691 - val_accuracy: 0.8813
# Epoch 37/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4772 - accuracy: 0.8611 - val_loss: 0.4598 - val_accuracy: 0.8767
# Epoch 38/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4681 - accuracy: 0.8562 - val_loss: 0.4506 - val_accuracy: 0.8858
# Epoch 39/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4590 - accuracy: 0.8581 - val_loss: 0.4416 - val_accuracy: 0.8904
# Epoch 40/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4495 - accuracy: 0.8620 - val_loss: 0.4330 - val_accuracy: 0.8813
# Epoch 41/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4407 - accuracy: 0.8581 - val_loss: 0.4245 - val_accuracy: 0.8904
# Epoch 42/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4319 - accuracy: 0.8611 - val_loss: 0.4163 - val_accuracy: 0.8813
# Epoch 43/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4234 - accuracy: 0.8571 - val_loss: 0.4085 - val_accuracy: 0.8813
# Epoch 44/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4153 - accuracy: 0.8591 - val_loss: 0.4009 - val_accuracy: 0.8858
# Epoch 45/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4075 - accuracy: 0.8581 - val_loss: 0.3936 - val_accuracy: 0.8904
# Epoch 46/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3997 - accuracy: 0.8601 - val_loss: 0.3866 - val_accuracy: 0.8904
# Epoch 47/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3927 - accuracy: 0.8620 - val_loss: 0.3800 - val_accuracy: 0.8904
# Epoch 48/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3853 - accuracy: 0.8630 - val_loss: 0.3741 - val_accuracy: 0.8858
# Epoch 49/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3793 - accuracy: 0.8630 - val_loss: 0.3679 - val_accuracy: 0.8858
# Epoch 50/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3726 - accuracy: 0.8630 - val_loss: 0.3625 - val_accuracy: 0.8858
# Epoch 51/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3668 - accuracy: 0.8669 - val_loss: 0.3570 - val_accuracy: 0.8858
# Epoch 52/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.8650 - val_loss: 0.3523 - val_accuracy: 0.8858
# Epoch 53/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3554 - accuracy: 0.8659 - val_loss: 0.3482 - val_accuracy: 0.8858
# Epoch 54/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3510 - accuracy: 0.8630 - val_loss: 0.3435 - val_accuracy: 0.8995
# Epoch 55/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3461 - accuracy: 0.8689 - val_loss: 0.3397 - val_accuracy: 0.8995
# Epoch 56/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3420 - accuracy: 0.8659 - val_loss: 0.3361 - val_accuracy: 0.8995
# Epoch 57/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3382 - accuracy: 0.8699 - val_loss: 0.3328 - val_accuracy: 0.9041
# Epoch 58/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3340 - accuracy: 0.8659 - val_loss: 0.3299 - val_accuracy: 0.8995
# Epoch 59/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3308 - accuracy: 0.8689 - val_loss: 0.3274 - val_accuracy: 0.8995
# Epoch 60/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3273 - accuracy: 0.8669 - val_loss: 0.3253 - val_accuracy: 0.8904
# Epoch 61/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3242 - accuracy: 0.8679 - val_loss: 0.3217 - val_accuracy: 0.9041
# Epoch 62/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3212 - accuracy: 0.8708 - val_loss: 0.3204 - val_accuracy: 0.8995
# Epoch 63/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3184 - accuracy: 0.8679 - val_loss: 0.3172 - val_accuracy: 0.9041
# Epoch 64/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3159 - accuracy: 0.8718 - val_loss: 0.3152 - val_accuracy: 0.9041
# Epoch 65/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3136 - accuracy: 0.8738 - val_loss: 0.3141 - val_accuracy: 0.9041
# Epoch 66/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3110 - accuracy: 0.8718 - val_loss: 0.3130 - val_accuracy: 0.9041
# Epoch 67/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3087 - accuracy: 0.8718 - val_loss: 0.3113 - val_accuracy: 0.9041
# Epoch 68/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3067 - accuracy: 0.8689 - val_loss: 0.3086 - val_accuracy: 0.9041
# Epoch 69/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3050 - accuracy: 0.8748 - val_loss: 0.3068 - val_accuracy: 0.9087
# Epoch 70/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3029 - accuracy: 0.8777 - val_loss: 0.3055 - val_accuracy: 0.9087
# Epoch 71/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3005 - accuracy: 0.8767 - val_loss: 0.3038 - val_accuracy: 0.9087
# Epoch 72/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2998 - accuracy: 0.8708 - val_loss: 0.3029 - val_accuracy: 0.9087
# Epoch 73/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2976 - accuracy: 0.8757 - val_loss: 0.3025 - val_accuracy: 0.9087
# Epoch 74/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2959 - accuracy: 0.8816 - val_loss: 0.3005 - val_accuracy: 0.9087
# Epoch 75/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2950 - accuracy: 0.8728 - val_loss: 0.2995 - val_accuracy: 0.9087
# Epoch 76/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2926 - accuracy: 0.8777 - val_loss: 0.2980 - val_accuracy: 0.9178
# Epoch 77/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2916 - accuracy: 0.8787 - val_loss: 0.2980 - val_accuracy: 0.9087
# Epoch 78/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2900 - accuracy: 0.8777 - val_loss: 0.2967 - val_accuracy: 0.9087
# Epoch 79/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2894 - accuracy: 0.8777 - val_loss: 0.2961 - val_accuracy: 0.9087
# Epoch 80/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2876 - accuracy: 0.8787 - val_loss: 0.2952 - val_accuracy: 0.9087
# Epoch 81/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2864 - accuracy: 0.8836 - val_loss: 0.2951 - val_accuracy: 0.9132
# Epoch 82/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2847 - accuracy: 0.8806 - val_loss: 0.2955 - val_accuracy: 0.9087
# Epoch 83/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2840 - accuracy: 0.8816 - val_loss: 0.2923 - val_accuracy: 0.9178
# Epoch 84/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2831 - accuracy: 0.8816 - val_loss: 0.2926 - val_accuracy: 0.9132
# Epoch 85/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2820 - accuracy: 0.8816 - val_loss: 0.2941 - val_accuracy: 0.9087
# Epoch 86/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2813 - accuracy: 0.8806 - val_loss: 0.2917 - val_accuracy: 0.9178
# Epoch 87/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2797 - accuracy: 0.8845 - val_loss: 0.2903 - val_accuracy: 0.9224
# Epoch 88/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2789 - accuracy: 0.8894 - val_loss: 0.2910 - val_accuracy: 0.9132
# Epoch 89/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2784 - accuracy: 0.8826 - val_loss: 0.2884 - val_accuracy: 0.9224
# Epoch 90/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2772 - accuracy: 0.8885 - val_loss: 0.2894 - val_accuracy: 0.9178
# Epoch 91/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2770 - accuracy: 0.8855 - val_loss: 0.2895 - val_accuracy: 0.9178
# Epoch 92/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2749 - accuracy: 0.8836 - val_loss: 0.2867 - val_accuracy: 0.9224
# Epoch 93/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2745 - accuracy: 0.8885 - val_loss: 0.2878 - val_accuracy: 0.9178
# Epoch 94/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2735 - accuracy: 0.8875 - val_loss: 0.2858 - val_accuracy: 0.9224
# Epoch 95/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2728 - accuracy: 0.8914 - val_loss: 0.2857 - val_accuracy: 0.9224
# Epoch 96/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2720 - accuracy: 0.8865 - val_loss: 0.2845 - val_accuracy: 0.9178
# Epoch 97/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2704 - accuracy: 0.8894 - val_loss: 0.2836 - val_accuracy: 0.9178
# Epoch 98/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2704 - accuracy: 0.8875 - val_loss: 0.2832 - val_accuracy: 0.9178
# Epoch 99/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2706 - accuracy: 0.8914 - val_loss: 0.2856 - val_accuracy: 0.9178
# Epoch 100/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2694 - accuracy: 0.8885 - val_loss: 0.2855 - val_accuracy: 0.9178

# %% [markdown]
# Most már láthatod, hogy a modell edzésben van! A számok alapján láthatja, hogy a veszteség csökken, a pontosság pedig nő az idő múlásával. Ezen a ponton kísérletezhet a hiperparaméterekkel és a neurális hálózat architektúrájával. Futtassa le újra a cellákat, hogy megnézze, hogyan változott a képzés, ha módosította a hiperparamétereket.

# %% [markdown]
# Ha elégedett a végleges modellel, ki tudjuk értékelni a tesztkészleten. A tesztkészleten való pontosság megállapításához futtassuk le ezt a kódrészletet:

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3288 - accuracy: 0.8539
# 0.853881299495697

# %% [markdown]
# Azért van az 1-es index a model.evaluate függvény után, mert a függvény a veszteséget adja vissza első elemként, a pontosságot pedig második elemként. Ha csak a pontosságot szeretnénk kiadni, egyszerűen lépjünk be a második elembe (amely 1-gyel van indexelve, mivel az első elem indexelése 0-ról indul).
#
# Az adathalmaz felosztásának véletlenszerűsége, valamint a súlyok inicializálása miatt a számok és a grafikon minden egyes alkalommal, amikor a notebookot futtatjuk, kissé különbözni fognak. Ennek ellenére a tesztek pontosságának 80% és 95% között kell lennie, ha a fent megadott architektúrát követtük!

# %% [markdown]
# És meg is van, meg is van a legelső neurális hálózatod, és be is tanítottad! Gratulálok!
#
# Összefoglalva: Az első neurális hálózatunk kódolásához mindössze néhány sornyi kódra volt szükség:
# *   Az architektúrát a Keras szekvenciális modellel adjuk meg.
# *   Néhány beállításunkat (optimalizáló, veszteségfüggvény, követendő metrikák) a model.compile segítségével adjuk meg.
# *   A modellünket betanítjuk (megtaláljuk a legjobb paramétereket az architektúránkhoz) a képzési adatokkal a model.fit segítségével.
# *   Kiértékeljük a modellünket a tesztkészleten a model.evaluate segítségével.

# %% [markdown]
# # A veszteség és a pontosság vizualizálása
# Beszéltünk a túlillesztésről és néhány regularizációs technikáról. Honnan tudjuk, hogy a modellünk jelenleg túlilleszkedik-e?
#
# Azt tehetjük, hogy a képzési veszteséget és a val loss-t ábrázoljuk az eltelt epochák számának függvényében. Néhány szép grafikon megjelenítéséhez a matplotlib csomagot fogjuk használni. Szokás szerint importálnunk kell a használni kívánt kódot:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Ezután szeretnénk megjeleníteni a képzési veszteséget és a validálási veszteséget. Ehhez futtassa ezt a kódrészletet:
#
# A fenti kódrészlet minden egyes sorát megmagyarázzuk. Az első két sor azt mondja, hogy a veszteséget és a val_loss-t akarjuk ábrázolni. A harmadik sor megadja a grafikon címét: "Model Loss". A negyedik és az ötödik sor megmondja, hogy az y és x tengelyt mivel kell jelölni. A hatodik sor tartalmazza a grafikonunk legendáját, és a legenda helye a jobb felső sarokban lesz. A hetedik sor pedig megmondja a Jupyter notebooknak, hogy jelenítse meg a grafikont.
#
# A Jupyter notebookunknak valahogy így kell kinéznie:

# %%
#We want to visualize the training loss and the validation loss like this:
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %% [markdown]
# Ugyanezt megtehetjük a képzési pontosság és a validálási pontosság ábrázolásához az alábbi kóddal:

# %%
plt.plot(hist.history['accuracy'])#acc
plt.plot(hist.history['val_accuracy'])#val_acc
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# Mivel a modellünk javulásai a képzési halmazon némileg megegyeznek a validálási halmaz javulásaival, nem úgy tűnik, hogy a modellünkben a túlillesztés hatalmas problémát jelentene.
#
# Összegzés: A matplotlib segítségével megjelenítjük a képzési és validálási veszteséget / pontosságot az idő múlásával, hogy lássuk, van-e túlilleszkedés a modellünkben.

# %% [markdown]
# # Regularizáció hozzáadása a neurális hálózatunkhoz
# Ahhoz, hogy regularizációt vezessünk be neurális hálózatunkba, fogalmazzunk egy olyan neurális hálózattal, amely rosszul overfiteli a képzési halmazunkat. Ezt nevezzük 2-es modellnek.

# %%
model_2 = Sequential([
    Dense(1000, activation='relu', input_shape=(10,)),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1, activation='sigmoid'),
])
model_2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_2 = model_2.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 3s 57ms/step - loss: 0.4547 - accuracy: 0.7671 - val_loss: 0.3404 - val_accuracy: 0.8721
# Epoch 2/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.3240 - accuracy: 0.8601 - val_loss: 0.3193 - val_accuracy: 0.8767
# Epoch 3/100
# 32/32 [==============================] - 2s 50ms/step - loss: 0.2934 - accuracy: 0.8728 - val_loss: 0.3645 - val_accuracy: 0.8904
# Epoch 4/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.2759 - accuracy: 0.8865 - val_loss: 0.3188 - val_accuracy: 0.8858
# Epoch 5/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.2668 - accuracy: 0.8777 - val_loss: 0.3039 - val_accuracy: 0.8950
# Epoch 6/100
# 32/32 [==============================] - 2s 74ms/step - loss: 0.2510 - accuracy: 0.8992 - val_loss: 0.3019 - val_accuracy: 0.8950
# Epoch 7/100
# 32/32 [==============================] - 2s 54ms/step - loss: 0.2480 - accuracy: 0.9051 - val_loss: 0.3522 - val_accuracy: 0.8858
# Epoch 8/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.2729 - accuracy: 0.8953 - val_loss: 0.3489 - val_accuracy: 0.8995
# Epoch 9/100
# 32/32 [==============================] - 2s 47ms/step - loss: 0.2524 - accuracy: 0.9061 - val_loss: 0.3012 - val_accuracy: 0.9087
# Epoch 10/100
# 32/32 [==============================] - 2s 48ms/step - loss: 0.2184 - accuracy: 0.9080 - val_loss: 0.3411 - val_accuracy: 0.8904
# Epoch 11/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.2248 - accuracy: 0.9100 - val_loss: 0.3109 - val_accuracy: 0.8995
# Epoch 12/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.2226 - accuracy: 0.9090 - val_loss: 0.3089 - val_accuracy: 0.9041
# Epoch 13/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.2378 - accuracy: 0.9022 - val_loss: 0.3479 - val_accuracy: 0.8767
# Epoch 14/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.2005 - accuracy: 0.9159 - val_loss: 0.3763 - val_accuracy: 0.9132
# Epoch 15/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.1931 - accuracy: 0.9256 - val_loss: 0.3718 - val_accuracy: 0.9041
# Epoch 16/100
# 32/32 [==============================] - 2s 50ms/step - loss: 0.1989 - accuracy: 0.9217 - val_loss: 0.3302 - val_accuracy: 0.9041
# Epoch 17/100
# 32/32 [==============================] - 2s 49ms/step - loss: 0.2175 - accuracy: 0.9168 - val_loss: 0.3658 - val_accuracy: 0.8767
# Epoch 18/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.2223 - accuracy: 0.9051 - val_loss: 0.3080 - val_accuracy: 0.9269
# Epoch 19/100
# 32/32 [==============================] - 2s 47ms/step - loss: 0.1888 - accuracy: 0.9217 - val_loss: 0.3224 - val_accuracy: 0.9041
# Epoch 20/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1883 - accuracy: 0.9247 - val_loss: 0.3400 - val_accuracy: 0.9132
# Epoch 21/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1909 - accuracy: 0.9139 - val_loss: 0.3442 - val_accuracy: 0.8950
# Epoch 22/100
# 32/32 [==============================] - 2s 53ms/step - loss: 0.1870 - accuracy: 0.9247 - val_loss: 0.3278 - val_accuracy: 0.9132
# Epoch 23/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.1864 - accuracy: 0.9266 - val_loss: 0.3394 - val_accuracy: 0.9041
# Epoch 24/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.1931 - accuracy: 0.9198 - val_loss: 0.3723 - val_accuracy: 0.8995
# Epoch 25/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1708 - accuracy: 0.9286 - val_loss: 0.4411 - val_accuracy: 0.8904
# Epoch 26/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1785 - accuracy: 0.9247 - val_loss: 0.3641 - val_accuracy: 0.9041
# Epoch 27/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1637 - accuracy: 0.9315 - val_loss: 0.4010 - val_accuracy: 0.8904
# Epoch 28/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1691 - accuracy: 0.9305 - val_loss: 0.3766 - val_accuracy: 0.9178
# Epoch 29/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.2285 - accuracy: 0.9041 - val_loss: 0.3262 - val_accuracy: 0.8995
# Epoch 30/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.2138 - accuracy: 0.9188 - val_loss: 0.3539 - val_accuracy: 0.8904
# Epoch 31/100
# 32/32 [==============================] - 2s 56ms/step - loss: 0.1819 - accuracy: 0.9227 - val_loss: 0.3350 - val_accuracy: 0.9087
# Epoch 32/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.1637 - accuracy: 0.9305 - val_loss: 0.3679 - val_accuracy: 0.8950
# Epoch 33/100
# 32/32 [==============================] - 2s 64ms/step - loss: 0.1652 - accuracy: 0.9344 - val_loss: 0.3930 - val_accuracy: 0.9087
# Epoch 34/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1781 - accuracy: 0.9276 - val_loss: 0.3877 - val_accuracy: 0.9224
# Epoch 35/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1950 - accuracy: 0.9305 - val_loss: 0.3203 - val_accuracy: 0.8995
# Epoch 36/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1752 - accuracy: 0.9295 - val_loss: 0.3683 - val_accuracy: 0.8950
# Epoch 37/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1633 - accuracy: 0.9374 - val_loss: 0.3629 - val_accuracy: 0.8813
# Epoch 38/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.1687 - accuracy: 0.9354 - val_loss: 0.4436 - val_accuracy: 0.8950
# Epoch 39/100
# 32/32 [==============================] - 2s 48ms/step - loss: 0.1672 - accuracy: 0.9305 - val_loss: 0.3613 - val_accuracy: 0.9178
# Epoch 40/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.1548 - accuracy: 0.9403 - val_loss: 0.4454 - val_accuracy: 0.8904
# Epoch 41/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.1737 - accuracy: 0.9247 - val_loss: 0.3316 - val_accuracy: 0.8995
# Epoch 42/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.1659 - accuracy: 0.9374 - val_loss: 0.4381 - val_accuracy: 0.9224
# Epoch 43/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1638 - accuracy: 0.9374 - val_loss: 0.4233 - val_accuracy: 0.8950
# Epoch 44/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1747 - accuracy: 0.9344 - val_loss: 0.3840 - val_accuracy: 0.8995
# Epoch 45/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.1888 - accuracy: 0.9237 - val_loss: 0.3589 - val_accuracy: 0.9041
# Epoch 46/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1704 - accuracy: 0.9354 - val_loss: 0.3528 - val_accuracy: 0.9087
# Epoch 47/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1681 - accuracy: 0.9335 - val_loss: 0.4212 - val_accuracy: 0.8950
# Epoch 48/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1641 - accuracy: 0.9344 - val_loss: 0.4547 - val_accuracy: 0.8858
# Epoch 49/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.1577 - accuracy: 0.9452 - val_loss: 0.4109 - val_accuracy: 0.9041
# Epoch 50/100
# 32/32 [==============================] - 3s 102ms/step - loss: 0.1489 - accuracy: 0.9472 - val_loss: 0.4571 - val_accuracy: 0.8950
# Epoch 51/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.1531 - accuracy: 0.9423 - val_loss: 0.5001 - val_accuracy: 0.9041
# Epoch 52/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1703 - accuracy: 0.9315 - val_loss: 0.4692 - val_accuracy: 0.8904
# Epoch 53/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1974 - accuracy: 0.9168 - val_loss: 0.3663 - val_accuracy: 0.8950
# Epoch 54/100
# 32/32 [==============================] - 1s 44ms/step - loss: 0.1681 - accuracy: 0.9384 - val_loss: 0.3880 - val_accuracy: 0.8858
# Epoch 55/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1715 - accuracy: 0.9217 - val_loss: 0.3973 - val_accuracy: 0.9132
# Epoch 56/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1649 - accuracy: 0.9315 - val_loss: 0.4179 - val_accuracy: 0.8995
# Epoch 57/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.1378 - accuracy: 0.9442 - val_loss: 0.4737 - val_accuracy: 0.9224
# Epoch 58/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.1469 - accuracy: 0.9452 - val_loss: 0.4760 - val_accuracy: 0.8950
# Epoch 59/100
# 32/32 [==============================] - 2s 48ms/step - loss: 0.1490 - accuracy: 0.9423 - val_loss: 0.4753 - val_accuracy: 0.9087
# Epoch 60/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1391 - accuracy: 0.9511 - val_loss: 0.4810 - val_accuracy: 0.8950
# Epoch 61/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1459 - accuracy: 0.9462 - val_loss: 0.4438 - val_accuracy: 0.9178
# Epoch 62/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1656 - accuracy: 0.9403 - val_loss: 0.4452 - val_accuracy: 0.8904
# Epoch 63/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1508 - accuracy: 0.9344 - val_loss: 0.5162 - val_accuracy: 0.8995
# Epoch 64/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1448 - accuracy: 0.9452 - val_loss: 0.4923 - val_accuracy: 0.8858
# Epoch 65/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1424 - accuracy: 0.9432 - val_loss: 0.3840 - val_accuracy: 0.8950
# Epoch 66/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.1437 - accuracy: 0.9384 - val_loss: 0.4923 - val_accuracy: 0.8995
# Epoch 67/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.1317 - accuracy: 0.9442 - val_loss: 0.4878 - val_accuracy: 0.9178
# Epoch 68/100
# 32/32 [==============================] - 2s 55ms/step - loss: 0.1253 - accuracy: 0.9472 - val_loss: 0.6063 - val_accuracy: 0.8858
# Epoch 69/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1321 - accuracy: 0.9452 - val_loss: 0.5154 - val_accuracy: 0.8995
# Epoch 70/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1722 - accuracy: 0.9325 - val_loss: 0.4523 - val_accuracy: 0.9224
# Epoch 71/100
# 32/32 [==============================] - 2s 47ms/step - loss: 0.1645 - accuracy: 0.9325 - val_loss: 0.4251 - val_accuracy: 0.8950
# Epoch 72/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1658 - accuracy: 0.9354 - val_loss: 0.3278 - val_accuracy: 0.9041
# Epoch 73/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1553 - accuracy: 0.9403 - val_loss: 0.6181 - val_accuracy: 0.8950
# Epoch 74/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1502 - accuracy: 0.9472 - val_loss: 0.3875 - val_accuracy: 0.9224
# Epoch 75/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.1435 - accuracy: 0.9452 - val_loss: 0.4314 - val_accuracy: 0.8995
# Epoch 76/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.1145 - accuracy: 0.9560 - val_loss: 0.5478 - val_accuracy: 0.8995
# Epoch 77/100
# 32/32 [==============================] - 2s 50ms/step - loss: 0.1245 - accuracy: 0.9521 - val_loss: 0.4448 - val_accuracy: 0.8995
# Epoch 78/100
# 32/32 [==============================] - 1s 44ms/step - loss: 0.1573 - accuracy: 0.9364 - val_loss: 0.4550 - val_accuracy: 0.9087
# Epoch 79/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1326 - accuracy: 0.9452 - val_loss: 0.4277 - val_accuracy: 0.9132
# Epoch 80/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1227 - accuracy: 0.9491 - val_loss: 0.4437 - val_accuracy: 0.9132
# Epoch 81/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1048 - accuracy: 0.9589 - val_loss: 0.5569 - val_accuracy: 0.8904
# Epoch 82/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1137 - accuracy: 0.9560 - val_loss: 0.5536 - val_accuracy: 0.9224
# Epoch 83/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1186 - accuracy: 0.9530 - val_loss: 0.6739 - val_accuracy: 0.8950
# Epoch 84/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.1150 - accuracy: 0.9511 - val_loss: 0.5735 - val_accuracy: 0.9041
# Epoch 85/100
# 32/32 [==============================] - 2s 73ms/step - loss: 0.1260 - accuracy: 0.9442 - val_loss: 0.4713 - val_accuracy: 0.9178
# Epoch 86/100
# 32/32 [==============================] - 2s 47ms/step - loss: 0.1273 - accuracy: 0.9423 - val_loss: 0.5262 - val_accuracy: 0.9087
# Epoch 87/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1139 - accuracy: 0.9530 - val_loss: 0.5930 - val_accuracy: 0.9041
# Epoch 88/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.1465 - accuracy: 0.9442 - val_loss: 0.2836 - val_accuracy: 0.9087
# Epoch 89/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.1605 - accuracy: 0.9335 - val_loss: 0.3068 - val_accuracy: 0.9041
# Epoch 90/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.1408 - accuracy: 0.9491 - val_loss: 0.4895 - val_accuracy: 0.9041
# Epoch 91/100
# 32/32 [==============================] - 1s 45ms/step - loss: 0.1111 - accuracy: 0.9530 - val_loss: 0.4507 - val_accuracy: 0.9132
# Epoch 92/100
# 32/32 [==============================] - 2s 51ms/step - loss: 0.1137 - accuracy: 0.9550 - val_loss: 0.5093 - val_accuracy: 0.8858
# Epoch 93/100
# 32/32 [==============================] - 2s 74ms/step - loss: 0.1056 - accuracy: 0.9550 - val_loss: 0.5582 - val_accuracy: 0.8950
# Epoch 94/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.1175 - accuracy: 0.9511 - val_loss: 0.5921 - val_accuracy: 0.8995
# Epoch 95/100
# 32/32 [==============================] - 2s 50ms/step - loss: 0.1207 - accuracy: 0.9501 - val_loss: 0.5766 - val_accuracy: 0.9087
# Epoch 96/100
# 32/32 [==============================] - 2s 47ms/step - loss: 0.1093 - accuracy: 0.9550 - val_loss: 0.5014 - val_accuracy: 0.9224
# Epoch 97/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.0958 - accuracy: 0.9609 - val_loss: 0.6055 - val_accuracy: 0.8950
# Epoch 98/100
# 32/32 [==============================] - 1s 47ms/step - loss: 0.0977 - accuracy: 0.9569 - val_loss: 0.5265 - val_accuracy: 0.9087
# Epoch 99/100
# 32/32 [==============================] - 1s 46ms/step - loss: 0.1785 - accuracy: 0.9227 - val_loss: 0.4170 - val_accuracy: 0.9087
# Epoch 100/100
# 32/32 [==============================] - 2s 47ms/step - loss: 0.1321 - accuracy: 0.9452 - val_loss: 0.6180 - val_accuracy: 0.8950

# %% [markdown]
# Itt egy sokkal nagyobb modellt készítettünk, és az Adam optimalizálót használtuk. Az Adam az egyik leggyakrabban használt optimalizáló, amely néhány finomítást ad a sztochasztikus gradiens ereszkedéshez, hogy gyorsabban elérje az alsó veszteségfüggvényt. Ha lefuttatjuk ezt a kódot, és az alábbi kód segítségével ábrázoljuk a veszteséggrafikonokat a hist_2-re (figyeljük meg, hogy a kód ugyanaz, kivéve, hogy a 'hist' helyett a 'hist_2'-t használjuk):

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %% [markdown]
# Ez a túlillesztés egyértelmű jele. A képzési veszteség csökken, de a validálási veszteség jóval a képzési veszteség felett van és növekszik (a 20. epocha fordulópontján túl). Ha az alábbi kód segítségével ábrázoljuk a pontosságot:

# %%
plt.plot(hist_2.history['accuracy'])#acc
plt.plot(hist_2.history['val_accuracy'])#val_acc
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# Egyértelműbb eltérést láthatunk a vonat és a validálás pontossága között is:

# %% [markdown]
# Most próbáljunk ki néhány stratégiát a túlillesztés csökkentésére (eltekintve attól, hogy az architektúránkat visszaváltoztatjuk az első modellünkre). Három stratégiát vezettünk be a túlillesztés csökkentésére.
#
# A három közül itt az L2 regularizációt és a dropoutot fogjuk beépíteni. Azért nem adunk hozzá early stoppingot itt, mert miután az első két stratégiát használtuk, a validációs veszteség nem veszi fel a fent látható U alakot, és így a korai stopping nem lesz olyan hatékony.

# %% [markdown]
# # Alulillesztési feladat

# %%
model_2 = Sequential([
    Dense(1000, activation='relu', input_shape=(10,)),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1, activation='sigmoid'),
])
model_2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_2 = model_2.fit(X_train, Y_train,
          batch_size=42, epochs=10,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 25/25 [==============================] - 4s 62ms/step - loss: 0.5043 - accuracy: 0.7485 - val_loss: 0.3366 - val_accuracy: 0.8950
# Epoch 2/10
# 25/25 [==============================] - 1s 53ms/step - loss: 0.3427 - accuracy: 0.8689 - val_loss: 0.3182 - val_accuracy: 0.8767
# Epoch 3/10
# 25/25 [==============================] - 1s 53ms/step - loss: 0.2958 - accuracy: 0.8865 - val_loss: 0.3885 - val_accuracy: 0.8539
# Epoch 4/10
# 25/25 [==============================] - 1s 53ms/step - loss: 0.2791 - accuracy: 0.8787 - val_loss: 0.3207 - val_accuracy: 0.9132
# Epoch 5/10
# 25/25 [==============================] - 1s 53ms/step - loss: 0.2649 - accuracy: 0.8992 - val_loss: 0.3489 - val_accuracy: 0.8721
# Epoch 6/10
# 25/25 [==============================] - 1s 52ms/step - loss: 0.2289 - accuracy: 0.9022 - val_loss: 0.3893 - val_accuracy: 0.8813
# Epoch 7/10
# 25/25 [==============================] - 2s 73ms/step - loss: 0.2446 - accuracy: 0.8963 - val_loss: 0.3347 - val_accuracy: 0.9087
# Epoch 8/10
# 25/25 [==============================] - 2s 85ms/step - loss: 0.2383 - accuracy: 0.8992 - val_loss: 0.3103 - val_accuracy: 0.8950
# Epoch 9/10
# 25/25 [==============================] - 2s 70ms/step - loss: 0.2100 - accuracy: 0.9129 - val_loss: 0.3124 - val_accuracy: 0.9087
# Epoch 10/10
# 25/25 [==============================] - 1s 57ms/step - loss: 0.2451 - accuracy: 0.8894 - val_loss: 0.3154 - val_accuracy: 0.8858

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist_2.history['accuracy'])#acc
plt.plot(hist_2.history['val_accuracy'])#val_acc
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# # Túltanítás 2

# %%
model_2 = Sequential([
    Dense(1000, activation='relu', input_shape=(10,)),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1, activation='sigmoid'),
])
model_2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_2 = model_2.fit(X_train, Y_train,
          batch_size=42, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 25/25 [==============================] - 4s 88ms/step - loss: 0.4747 - accuracy: 0.7583 - val_loss: 0.3548 - val_accuracy: 0.8767
# Epoch 2/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.3321 - accuracy: 0.8581 - val_loss: 0.3705 - val_accuracy: 0.8721
# Epoch 3/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.3487 - accuracy: 0.8640 - val_loss: 0.3061 - val_accuracy: 0.8904
# Epoch 4/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.2833 - accuracy: 0.8806 - val_loss: 0.3691 - val_accuracy: 0.8767
# Epoch 5/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.2542 - accuracy: 0.8982 - val_loss: 0.3980 - val_accuracy: 0.8904
# Epoch 6/100
# 25/25 [==============================] - 1s 48ms/step - loss: 0.3371 - accuracy: 0.8630 - val_loss: 0.3687 - val_accuracy: 0.8904
# Epoch 7/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.2481 - accuracy: 0.9041 - val_loss: 0.3429 - val_accuracy: 0.9087
# Epoch 8/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.2597 - accuracy: 0.8924 - val_loss: 0.3166 - val_accuracy: 0.8995
# Epoch 9/100
# 25/25 [==============================] - 1s 57ms/step - loss: 0.2211 - accuracy: 0.9080 - val_loss: 0.3188 - val_accuracy: 0.8950
# Epoch 10/100
# 25/25 [==============================] - 2s 76ms/step - loss: 0.2488 - accuracy: 0.8953 - val_loss: 0.3264 - val_accuracy: 0.8950
# Epoch 11/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.2326 - accuracy: 0.9129 - val_loss: 0.3682 - val_accuracy: 0.8858
# Epoch 12/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.2325 - accuracy: 0.8933 - val_loss: 0.3623 - val_accuracy: 0.8904
# Epoch 13/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.2038 - accuracy: 0.9237 - val_loss: 0.3216 - val_accuracy: 0.8950
# Epoch 14/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.2160 - accuracy: 0.9129 - val_loss: 0.4178 - val_accuracy: 0.8676
# Epoch 15/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.2223 - accuracy: 0.9100 - val_loss: 0.3341 - val_accuracy: 0.8950
# Epoch 16/100
# 25/25 [==============================] - 1s 55ms/step - loss: 0.1900 - accuracy: 0.9237 - val_loss: 0.3425 - val_accuracy: 0.9132
# Epoch 17/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1944 - accuracy: 0.9266 - val_loss: 0.3497 - val_accuracy: 0.9224
# Epoch 18/100
# 25/25 [==============================] - 1s 55ms/step - loss: 0.1897 - accuracy: 0.9217 - val_loss: 0.3491 - val_accuracy: 0.8950
# Epoch 19/100
# 25/25 [==============================] - 2s 69ms/step - loss: 0.1838 - accuracy: 0.9188 - val_loss: 0.3412 - val_accuracy: 0.9132
# Epoch 20/100
# 25/25 [==============================] - 2s 78ms/step - loss: 0.1826 - accuracy: 0.9188 - val_loss: 0.3923 - val_accuracy: 0.8858
# Epoch 21/100
# 25/25 [==============================] - 2s 77ms/step - loss: 0.1976 - accuracy: 0.9237 - val_loss: 0.3678 - val_accuracy: 0.9041
# Epoch 22/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.2034 - accuracy: 0.9129 - val_loss: 0.3554 - val_accuracy: 0.9132
# Epoch 23/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1945 - accuracy: 0.9247 - val_loss: 0.3549 - val_accuracy: 0.9087
# Epoch 24/100
# 25/25 [==============================] - 1s 57ms/step - loss: 0.1748 - accuracy: 0.9295 - val_loss: 0.3891 - val_accuracy: 0.8950
# Epoch 25/100
# 25/25 [==============================] - 1s 55ms/step - loss: 0.1886 - accuracy: 0.9266 - val_loss: 0.3663 - val_accuracy: 0.8950
# Epoch 26/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1784 - accuracy: 0.9237 - val_loss: 0.3539 - val_accuracy: 0.8950
# Epoch 27/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1690 - accuracy: 0.9335 - val_loss: 0.3964 - val_accuracy: 0.8995
# Epoch 28/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.1733 - accuracy: 0.9344 - val_loss: 0.3528 - val_accuracy: 0.9087
# Epoch 29/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.1910 - accuracy: 0.9119 - val_loss: 0.4085 - val_accuracy: 0.8904
# Epoch 30/100
# 25/25 [==============================] - 2s 78ms/step - loss: 0.2289 - accuracy: 0.9051 - val_loss: 0.3392 - val_accuracy: 0.8813
# Epoch 31/100
# 25/25 [==============================] - 2s 78ms/step - loss: 0.1873 - accuracy: 0.9266 - val_loss: 0.3711 - val_accuracy: 0.8950
# Epoch 32/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1685 - accuracy: 0.9305 - val_loss: 0.4177 - val_accuracy: 0.8950
# Epoch 33/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.1659 - accuracy: 0.9374 - val_loss: 0.4050 - val_accuracy: 0.9178
# Epoch 34/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.1720 - accuracy: 0.9276 - val_loss: 0.3625 - val_accuracy: 0.9132
# Epoch 35/100
# 25/25 [==============================] - 1s 55ms/step - loss: 0.1632 - accuracy: 0.9276 - val_loss: 0.3858 - val_accuracy: 0.9178
# Epoch 36/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1600 - accuracy: 0.9384 - val_loss: 0.4222 - val_accuracy: 0.9041
# Epoch 37/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.1501 - accuracy: 0.9384 - val_loss: 0.4235 - val_accuracy: 0.9041
# Epoch 38/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1510 - accuracy: 0.9393 - val_loss: 0.4875 - val_accuracy: 0.8904
# Epoch 39/100
# 25/25 [==============================] - 2s 71ms/step - loss: 0.2223 - accuracy: 0.9100 - val_loss: 0.3367 - val_accuracy: 0.8995
# Epoch 40/100
# 25/25 [==============================] - 2s 82ms/step - loss: 0.1737 - accuracy: 0.9305 - val_loss: 0.3723 - val_accuracy: 0.8904
# Epoch 41/100
# 25/25 [==============================] - 2s 71ms/step - loss: 0.1661 - accuracy: 0.9315 - val_loss: 0.4163 - val_accuracy: 0.8950
# Epoch 42/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1782 - accuracy: 0.9335 - val_loss: 0.4343 - val_accuracy: 0.8995
# Epoch 43/100
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1604 - accuracy: 0.9364 - val_loss: 0.4243 - val_accuracy: 0.8995
# Epoch 44/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1530 - accuracy: 0.9364 - val_loss: 0.4018 - val_accuracy: 0.9041
# Epoch 45/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1580 - accuracy: 0.9442 - val_loss: 0.4227 - val_accuracy: 0.8995
# Epoch 46/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.1529 - accuracy: 0.9384 - val_loss: 0.4963 - val_accuracy: 0.8950
# Epoch 47/100
# 25/25 [==============================] - 1s 49ms/step - loss: 0.2048 - accuracy: 0.9217 - val_loss: 0.3300 - val_accuracy: 0.9178
# Epoch 48/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.1885 - accuracy: 0.9266 - val_loss: 0.3422 - val_accuracy: 0.9087
# Epoch 49/100
# 25/25 [==============================] - 2s 70ms/step - loss: 0.1618 - accuracy: 0.9413 - val_loss: 0.3535 - val_accuracy: 0.9178
# Epoch 50/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1869 - accuracy: 0.9217 - val_loss: 0.3506 - val_accuracy: 0.8995
# Epoch 51/100
# 25/25 [==============================] - 2s 70ms/step - loss: 0.1604 - accuracy: 0.9325 - val_loss: 0.4557 - val_accuracy: 0.8950
# Epoch 52/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.1823 - accuracy: 0.9295 - val_loss: 0.3838 - val_accuracy: 0.9041
# Epoch 53/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.1555 - accuracy: 0.9423 - val_loss: 0.3544 - val_accuracy: 0.8950
# Epoch 54/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.1587 - accuracy: 0.9335 - val_loss: 0.4436 - val_accuracy: 0.8950
# Epoch 55/100
# 25/25 [==============================] - 1s 50ms/step - loss: 0.1393 - accuracy: 0.9413 - val_loss: 0.4526 - val_accuracy: 0.9361
# Epoch 56/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1524 - accuracy: 0.9403 - val_loss: 0.4006 - val_accuracy: 0.8995
# Epoch 57/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1351 - accuracy: 0.9462 - val_loss: 0.4742 - val_accuracy: 0.8904
# Epoch 58/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1484 - accuracy: 0.9472 - val_loss: 0.4566 - val_accuracy: 0.9041
# Epoch 59/100
# 25/25 [==============================] - 2s 83ms/step - loss: 0.1454 - accuracy: 0.9403 - val_loss: 0.4588 - val_accuracy: 0.8950
# Epoch 60/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.1321 - accuracy: 0.9550 - val_loss: 0.5328 - val_accuracy: 0.8904
# Epoch 61/100
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1329 - accuracy: 0.9442 - val_loss: 0.4435 - val_accuracy: 0.8995
# Epoch 62/100
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1645 - accuracy: 0.9364 - val_loss: 0.4198 - val_accuracy: 0.9041
# Epoch 63/100
# 25/25 [==============================] - 1s 56ms/step - loss: 0.1715 - accuracy: 0.9364 - val_loss: 0.4571 - val_accuracy: 0.8858
# Epoch 64/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1741 - accuracy: 0.9295 - val_loss: 0.3472 - val_accuracy: 0.9269
# Epoch 65/100
# 25/25 [==============================] - 1s 56ms/step - loss: 0.1372 - accuracy: 0.9491 - val_loss: 0.4719 - val_accuracy: 0.8995
# Epoch 66/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1410 - accuracy: 0.9413 - val_loss: 0.4247 - val_accuracy: 0.9132
# Epoch 67/100
# 25/25 [==============================] - 1s 51ms/step - loss: 0.1561 - accuracy: 0.9364 - val_loss: 0.4447 - val_accuracy: 0.9178
# Epoch 68/100
# 25/25 [==============================] - 1s 58ms/step - loss: 0.1648 - accuracy: 0.9315 - val_loss: 0.4242 - val_accuracy: 0.9087
# Epoch 69/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1386 - accuracy: 0.9481 - val_loss: 0.3927 - val_accuracy: 0.8995
# Epoch 70/100
# 25/25 [==============================] - 2s 84ms/step - loss: 0.1200 - accuracy: 0.9521 - val_loss: 0.4892 - val_accuracy: 0.8995
# Epoch 71/100
# 25/25 [==============================] - 1s 56ms/step - loss: 0.1290 - accuracy: 0.9423 - val_loss: 0.4615 - val_accuracy: 0.9041
# Epoch 72/100
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1482 - accuracy: 0.9335 - val_loss: 0.5708 - val_accuracy: 0.8904
# Epoch 73/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1610 - accuracy: 0.9305 - val_loss: 0.5176 - val_accuracy: 0.9041
# Epoch 74/100
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1447 - accuracy: 0.9344 - val_loss: 0.3530 - val_accuracy: 0.9178
# Epoch 75/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1370 - accuracy: 0.9462 - val_loss: 0.4944 - val_accuracy: 0.9132
# Epoch 76/100
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1323 - accuracy: 0.9472 - val_loss: 0.4861 - val_accuracy: 0.9087
# Epoch 77/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1136 - accuracy: 0.9472 - val_loss: 0.5105 - val_accuracy: 0.9178
# Epoch 78/100
# 25/25 [==============================] - 2s 68ms/step - loss: 0.1151 - accuracy: 0.9511 - val_loss: 0.4749 - val_accuracy: 0.9224
# Epoch 79/100
# 25/25 [==============================] - 3s 131ms/step - loss: 0.1335 - accuracy: 0.9403 - val_loss: 0.5230 - val_accuracy: 0.8950
# Epoch 80/100
# 25/25 [==============================] - 1s 58ms/step - loss: 0.1315 - accuracy: 0.9403 - val_loss: 0.4706 - val_accuracy: 0.9087
# Epoch 81/100
# 25/25 [==============================] - 1s 55ms/step - loss: 0.1124 - accuracy: 0.9530 - val_loss: 0.4958 - val_accuracy: 0.9269
# Epoch 82/100
# 25/25 [==============================] - 1s 58ms/step - loss: 0.1475 - accuracy: 0.9384 - val_loss: 0.4765 - val_accuracy: 0.9132
# Epoch 83/100
# 25/25 [==============================] - 1s 57ms/step - loss: 0.1339 - accuracy: 0.9452 - val_loss: 0.5260 - val_accuracy: 0.8950
# Epoch 84/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1455 - accuracy: 0.9452 - val_loss: 0.4081 - val_accuracy: 0.9224
# Epoch 85/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.1258 - accuracy: 0.9521 - val_loss: 0.5543 - val_accuracy: 0.8904
# Epoch 86/100
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1582 - accuracy: 0.9305 - val_loss: 0.4937 - val_accuracy: 0.9087
# Epoch 87/100
# 25/25 [==============================] - 2s 70ms/step - loss: 0.1154 - accuracy: 0.9560 - val_loss: 0.5993 - val_accuracy: 0.8995
# Epoch 88/100
# 25/25 [==============================] - 2s 84ms/step - loss: 0.1134 - accuracy: 0.9560 - val_loss: 0.5005 - val_accuracy: 0.9087
# Epoch 89/100
# 25/25 [==============================] - 2s 72ms/step - loss: 0.1114 - accuracy: 0.9579 - val_loss: 0.5872 - val_accuracy: 0.8995
# Epoch 90/100
# 25/25 [==============================] - 1s 55ms/step - loss: 0.1481 - accuracy: 0.9315 - val_loss: 0.4641 - val_accuracy: 0.8950
# Epoch 91/100
# 25/25 [==============================] - 1s 55ms/step - loss: 0.1103 - accuracy: 0.9511 - val_loss: 0.5819 - val_accuracy: 0.9087
# Epoch 92/100
# 25/25 [==============================] - 1s 57ms/step - loss: 0.0963 - accuracy: 0.9569 - val_loss: 0.6127 - val_accuracy: 0.9087
# Epoch 93/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0925 - accuracy: 0.9599 - val_loss: 0.7034 - val_accuracy: 0.9041
# Epoch 94/100
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0921 - accuracy: 0.9599 - val_loss: 0.6240 - val_accuracy: 0.9269
# Epoch 95/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1007 - accuracy: 0.9521 - val_loss: 0.6337 - val_accuracy: 0.8995
# Epoch 96/100
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1165 - accuracy: 0.9530 - val_loss: 0.6995 - val_accuracy: 0.8904
# Epoch 97/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.1648 - accuracy: 0.9403 - val_loss: 0.3156 - val_accuracy: 0.9087
# Epoch 98/100
# 25/25 [==============================] - 2s 84ms/step - loss: 0.1602 - accuracy: 0.9305 - val_loss: 0.4095 - val_accuracy: 0.9087
# Epoch 99/100
# 25/25 [==============================] - 1s 58ms/step - loss: 0.1173 - accuracy: 0.9501 - val_loss: 0.4801 - val_accuracy: 0.8995
# Epoch 100/100
# 25/25 [==============================] - 1s 55ms/step - loss: 0.1136 - accuracy: 0.9501 - val_loss: 0.5266 - val_accuracy: 0.8950

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist_2.history['accuracy'])#acc
plt.plot(hist_2.history['val_accuracy'])#val_acc
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# Először is importáljuk a kódot, amelyre az L2 regularizációhoz és a kieséshez van szükségünk:

# %%
from tensorflow.python.keras import regularizers
from keras.layers import Dropout

# %% [markdown]
# Ezután a harmadik modellünket így határozzuk meg:

# %%
#To address the overfitting we see in Model 2, we'll incorporate L2 regularization and dropout in our third model here (Model 3).
model_3 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.3), # 1000 neuron kozul a 30%-at droppolja, azok helyet ujakat tesz
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.3),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])

# %% [markdown]
# Felismeri a Model 3 és a Model 2 közötti különbségeket? Két fő különbség van:
#
# Az L2-regulázás hozzáadásához vegyük észre, hogy minden egyes denses rétegünkben egy kis extra kódot adtunk hozzá, így:
# 1. különbség:
# kernel_regularizer=regularizers.l2(0.01) - Ez azt mondja a Kerasnak, hogy vegye figyelembe ezeknek a paramétereknek a négyzetértékeit a teljes veszteségfüggvényünkben, és súlyozza őket 0,01-gyel a veszteségfüggvényben.
#
# 2. különbség: A Dropout hozzáadásához egy új réteget adtunk hozzá, így:
# Dropout(0.3), - Ez azt jelenti, hogy az előző réteg neuronjai 0,3 valószínűséggel esnek ki a képzés során. Állítsuk össze és futtassuk le ugyanazokkal a paraméterekkel, mint a 2. modellünket (a túlilleszkedő):

# %%
model_3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_3 = model_3.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 4s 70ms/step - loss: 14.2511 - accuracy: 0.6262 - val_loss: 3.8816 - val_accuracy: 0.8813
# Epoch 2/100
# 32/32 [==============================] - 3s 90ms/step - loss: 1.6694 - accuracy: 0.8366 - val_loss: 0.6580 - val_accuracy: 0.8813
# Epoch 3/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.5645 - accuracy: 0.8611 - val_loss: 0.5011 - val_accuracy: 0.8813
# Epoch 4/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.5048 - accuracy: 0.8767 - val_loss: 0.4788 - val_accuracy: 0.9041
# Epoch 5/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.5064 - accuracy: 0.8562 - val_loss: 0.4658 - val_accuracy: 0.9087
# Epoch 6/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.4742 - accuracy: 0.8826 - val_loss: 0.4484 - val_accuracy: 0.9132
# Epoch 7/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4726 - accuracy: 0.8679 - val_loss: 0.4914 - val_accuracy: 0.8813
# Epoch 8/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.4943 - accuracy: 0.8689 - val_loss: 0.4498 - val_accuracy: 0.9041
# Epoch 9/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4779 - accuracy: 0.8845 - val_loss: 0.4897 - val_accuracy: 0.8767
# Epoch 10/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4546 - accuracy: 0.8845 - val_loss: 0.4304 - val_accuracy: 0.9178
# Epoch 11/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4670 - accuracy: 0.8767 - val_loss: 0.4420 - val_accuracy: 0.8950
# Epoch 12/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4530 - accuracy: 0.8845 - val_loss: 0.4339 - val_accuracy: 0.9132
# Epoch 13/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4626 - accuracy: 0.8767 - val_loss: 0.5240 - val_accuracy: 0.8447
# Epoch 14/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.4459 - accuracy: 0.8826 - val_loss: 0.4343 - val_accuracy: 0.8995
# Epoch 15/100
# 32/32 [==============================] - 2s 74ms/step - loss: 0.4730 - accuracy: 0.8620 - val_loss: 0.4894 - val_accuracy: 0.8813
# Epoch 16/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4562 - accuracy: 0.8757 - val_loss: 0.4325 - val_accuracy: 0.8950
# Epoch 17/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.4360 - accuracy: 0.8855 - val_loss: 0.4361 - val_accuracy: 0.8904
# Epoch 18/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4346 - accuracy: 0.8943 - val_loss: 0.4418 - val_accuracy: 0.9041
# Epoch 19/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4474 - accuracy: 0.8699 - val_loss: 0.4711 - val_accuracy: 0.8813
# Epoch 20/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4610 - accuracy: 0.8748 - val_loss: 0.4306 - val_accuracy: 0.8858
# Epoch 21/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4424 - accuracy: 0.8767 - val_loss: 0.4211 - val_accuracy: 0.9041
# Epoch 22/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4589 - accuracy: 0.8806 - val_loss: 0.4335 - val_accuracy: 0.8904
# Epoch 23/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.4300 - accuracy: 0.8885 - val_loss: 0.4464 - val_accuracy: 0.8858
# Epoch 24/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4378 - accuracy: 0.8875 - val_loss: 0.4219 - val_accuracy: 0.9132
# Epoch 25/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4386 - accuracy: 0.8806 - val_loss: 0.4459 - val_accuracy: 0.8858
# Epoch 26/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4509 - accuracy: 0.8767 - val_loss: 0.4587 - val_accuracy: 0.8813
# Epoch 27/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4527 - accuracy: 0.8777 - val_loss: 0.4247 - val_accuracy: 0.9178
# Epoch 28/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.4393 - accuracy: 0.8806 - val_loss: 0.4137 - val_accuracy: 0.9132
# Epoch 29/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4394 - accuracy: 0.8836 - val_loss: 0.4185 - val_accuracy: 0.9132
# Epoch 30/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4369 - accuracy: 0.8894 - val_loss: 0.4243 - val_accuracy: 0.8995
# Epoch 31/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4297 - accuracy: 0.8865 - val_loss: 0.4558 - val_accuracy: 0.8813
# Epoch 32/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.4172 - accuracy: 0.8826 - val_loss: 0.4207 - val_accuracy: 0.8995
# Epoch 33/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4400 - accuracy: 0.8796 - val_loss: 0.4923 - val_accuracy: 0.8721
# Epoch 34/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4330 - accuracy: 0.8904 - val_loss: 0.4406 - val_accuracy: 0.8904
# Epoch 35/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4188 - accuracy: 0.8865 - val_loss: 0.4163 - val_accuracy: 0.9087
# Epoch 36/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4260 - accuracy: 0.8816 - val_loss: 0.4410 - val_accuracy: 0.8813
# Epoch 37/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.4284 - accuracy: 0.8894 - val_loss: 0.4234 - val_accuracy: 0.8995
# Epoch 38/100
# 32/32 [==============================] - 2s 57ms/step - loss: 0.4382 - accuracy: 0.8689 - val_loss: 0.4131 - val_accuracy: 0.9087
# Epoch 39/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4471 - accuracy: 0.8787 - val_loss: 0.4534 - val_accuracy: 0.8813
# Epoch 40/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4328 - accuracy: 0.8963 - val_loss: 0.4280 - val_accuracy: 0.8950
# Epoch 41/100
# 32/32 [==============================] - 2s 69ms/step - loss: 0.4350 - accuracy: 0.8816 - val_loss: 0.4142 - val_accuracy: 0.9132
# Epoch 42/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.4354 - accuracy: 0.8845 - val_loss: 0.4150 - val_accuracy: 0.9087
# Epoch 43/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.4303 - accuracy: 0.8914 - val_loss: 0.4245 - val_accuracy: 0.8995
# Epoch 44/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.4280 - accuracy: 0.8894 - val_loss: 0.4343 - val_accuracy: 0.8904
# Epoch 45/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.4264 - accuracy: 0.8845 - val_loss: 0.4150 - val_accuracy: 0.8995
# Epoch 46/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.4134 - accuracy: 0.8904 - val_loss: 0.4253 - val_accuracy: 0.8995
# Epoch 47/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.4279 - accuracy: 0.8904 - val_loss: 0.4141 - val_accuracy: 0.9087
# Epoch 48/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.4235 - accuracy: 0.8826 - val_loss: 0.4128 - val_accuracy: 0.9132
# Epoch 49/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.4314 - accuracy: 0.8865 - val_loss: 0.4263 - val_accuracy: 0.9178
# Epoch 50/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4359 - accuracy: 0.8865 - val_loss: 0.4599 - val_accuracy: 0.8813
# Epoch 51/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4241 - accuracy: 0.8885 - val_loss: 0.4260 - val_accuracy: 0.8995
# Epoch 52/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4164 - accuracy: 0.8953 - val_loss: 0.4192 - val_accuracy: 0.8995
# Epoch 53/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4291 - accuracy: 0.8855 - val_loss: 0.4193 - val_accuracy: 0.9132
# Epoch 54/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.4300 - accuracy: 0.8865 - val_loss: 0.4181 - val_accuracy: 0.8995
# Epoch 55/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4207 - accuracy: 0.8777 - val_loss: 0.4408 - val_accuracy: 0.8904
# Epoch 56/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.4306 - accuracy: 0.8924 - val_loss: 0.4185 - val_accuracy: 0.8950
# Epoch 57/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.4271 - accuracy: 0.8914 - val_loss: 0.4214 - val_accuracy: 0.8995
# Epoch 58/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4151 - accuracy: 0.8943 - val_loss: 0.4163 - val_accuracy: 0.8950
# Epoch 59/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4285 - accuracy: 0.8894 - val_loss: 0.4333 - val_accuracy: 0.9132
# Epoch 60/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4315 - accuracy: 0.8865 - val_loss: 0.4175 - val_accuracy: 0.8995
# Epoch 61/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.4173 - accuracy: 0.8875 - val_loss: 0.4267 - val_accuracy: 0.8995
# Epoch 62/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4364 - accuracy: 0.8816 - val_loss: 0.4160 - val_accuracy: 0.9087
# Epoch 63/100
# 32/32 [==============================] - 2s 68ms/step - loss: 0.4358 - accuracy: 0.8738 - val_loss: 0.4419 - val_accuracy: 0.8813
# Epoch 64/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.4391 - accuracy: 0.8767 - val_loss: 0.4450 - val_accuracy: 0.8858
# Epoch 65/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4214 - accuracy: 0.8963 - val_loss: 0.4123 - val_accuracy: 0.9087
# Epoch 66/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4200 - accuracy: 0.8894 - val_loss: 0.4199 - val_accuracy: 0.8995
# Epoch 67/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4195 - accuracy: 0.8845 - val_loss: 0.4217 - val_accuracy: 0.9087
# Epoch 68/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4218 - accuracy: 0.8953 - val_loss: 0.4273 - val_accuracy: 0.8995
# Epoch 69/100
# 32/32 [==============================] - 2s 64ms/step - loss: 0.4366 - accuracy: 0.8748 - val_loss: 0.4142 - val_accuracy: 0.9087
# Epoch 70/100
# 32/32 [==============================] - 2s 70ms/step - loss: 0.4382 - accuracy: 0.8689 - val_loss: 0.4388 - val_accuracy: 0.8904
# Epoch 71/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.4278 - accuracy: 0.8904 - val_loss: 0.4196 - val_accuracy: 0.8995
# Epoch 72/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.4253 - accuracy: 0.8963 - val_loss: 0.4134 - val_accuracy: 0.9132
# Epoch 73/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4243 - accuracy: 0.8816 - val_loss: 0.4148 - val_accuracy: 0.9087
# Epoch 74/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.4113 - accuracy: 0.8953 - val_loss: 0.4441 - val_accuracy: 0.8904
# Epoch 75/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.4232 - accuracy: 0.8885 - val_loss: 0.4126 - val_accuracy: 0.9087
# Epoch 76/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4420 - accuracy: 0.8738 - val_loss: 0.5002 - val_accuracy: 0.8858
# Epoch 77/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.4540 - accuracy: 0.8796 - val_loss: 0.4331 - val_accuracy: 0.8950
# Epoch 78/100
# 32/32 [==============================] - 3s 92ms/step - loss: 0.4215 - accuracy: 0.8894 - val_loss: 0.4320 - val_accuracy: 0.8950
# Epoch 79/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4227 - accuracy: 0.8865 - val_loss: 0.4214 - val_accuracy: 0.9087
# Epoch 80/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4340 - accuracy: 0.8826 - val_loss: 0.4328 - val_accuracy: 0.8904
# Epoch 81/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4177 - accuracy: 0.8865 - val_loss: 0.4566 - val_accuracy: 0.8858
# Epoch 82/100
# 32/32 [==============================] - 2s 59ms/step - loss: 0.4293 - accuracy: 0.8826 - val_loss: 0.4112 - val_accuracy: 0.9087
# Epoch 83/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.4163 - accuracy: 0.8924 - val_loss: 0.4176 - val_accuracy: 0.9087
# Epoch 84/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.4242 - accuracy: 0.8914 - val_loss: 0.4125 - val_accuracy: 0.9087
# Epoch 85/100
# 32/32 [==============================] - 3s 89ms/step - loss: 0.4284 - accuracy: 0.8806 - val_loss: 0.4173 - val_accuracy: 0.9087
# Epoch 86/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.4249 - accuracy: 0.8914 - val_loss: 0.4146 - val_accuracy: 0.9041
# Epoch 87/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.4347 - accuracy: 0.8767 - val_loss: 0.4670 - val_accuracy: 0.8813
# Epoch 88/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.4216 - accuracy: 0.8933 - val_loss: 0.4389 - val_accuracy: 0.8904
# Epoch 89/100
# 32/32 [==============================] - 2s 66ms/step - loss: 0.4425 - accuracy: 0.8738 - val_loss: 0.4355 - val_accuracy: 0.9132
# Epoch 90/100
# 32/32 [==============================] - 2s 65ms/step - loss: 0.4417 - accuracy: 0.8787 - val_loss: 0.4344 - val_accuracy: 0.8950
# Epoch 91/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.4289 - accuracy: 0.8845 - val_loss: 0.4509 - val_accuracy: 0.8858
# Epoch 92/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.4345 - accuracy: 0.8816 - val_loss: 0.4174 - val_accuracy: 0.8995
# Epoch 93/100
# 32/32 [==============================] - 2s 61ms/step - loss: 0.4344 - accuracy: 0.8777 - val_loss: 0.4125 - val_accuracy: 0.9087
# Epoch 94/100
# 32/32 [==============================] - 2s 62ms/step - loss: 0.4172 - accuracy: 0.8973 - val_loss: 0.4205 - val_accuracy: 0.8995
# Epoch 95/100
# 32/32 [==============================] - 2s 58ms/step - loss: 0.4324 - accuracy: 0.8845 - val_loss: 0.4354 - val_accuracy: 0.8904
# Epoch 96/100
# 32/32 [==============================] - 2s 63ms/step - loss: 0.4321 - accuracy: 0.8767 - val_loss: 0.4944 - val_accuracy: 0.8813
# Epoch 97/100
# 32/32 [==============================] - 2s 72ms/step - loss: 0.4253 - accuracy: 0.8855 - val_loss: 0.4192 - val_accuracy: 0.8995
# Epoch 98/100
# 32/32 [==============================] - 3s 91ms/step - loss: 0.4343 - accuracy: 0.8865 - val_loss: 0.4177 - val_accuracy: 0.8995
# Epoch 99/100
# 32/32 [==============================] - 2s 67ms/step - loss: 0.4461 - accuracy: 0.8806 - val_loss: 0.4218 - val_accuracy: 0.9132
# Epoch 100/100
# 32/32 [==============================] - 2s 60ms/step - loss: 0.4342 - accuracy: 0.8738 - val_loss: 0.4371 - val_accuracy: 0.8995

# %% [markdown]
# És most rajzoljuk fel a veszteség és a pontosság grafikonjait. Észre fogja venni, hogy a veszteség sokkal nagyobb az elején, és ez azért van, mert megváltoztattuk a veszteségfüggvényünket. Ahhoz, hogy a veszteséget úgy ábrázoljuk, hogy az ablak 0 és 1,2 közé legyen nagyítva, egy további kódsort (plt.ylim) adunk hozzá az ábrázoláskor:

# %%
plt.plot(hist_3.history['loss'])
plt.plot(hist_3.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.2, bottom=0)
plt.show()

# %% [markdown]
# Láthatjuk, hogy a validációs veszteség sokkal jobban megfelel a képzési veszteségünknek. Ábrázoljuk a pontosságot hasonló kódrészlettel:

# %%
plt.plot(hist_3.history['accuracy'])#acc
plt.plot(hist_3.history['val_accuracy'])#val_acc
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# A 2. modellünkhöz képest jelentősen csökkentettük a túlillesztést! És így alkalmazzuk a regularizációs technikáinkat a túlillesztés csökkentésére a képzési halmazon.
#
# Összefoglalva: A túlillesztés kezelésére a következő stratégiákat kódolhatjuk be a modellünkbe, amelyek mindegyike körülbelül egy sornyi kódot tartalmaz:
# *   L2 Regularization
# *   Dropout
#
# Ha megjelenítjük a képzési / validálási veszteséget és a pontosságot, láthatjuk, hogy ezek a kiegészítések segítettek a túlillesztés kezelésében!

# %% [markdown]
# # Megoldandó feladatok:
# 1.   Hozd müködésbe a kódot mi hiányzik?
# 2.   Próbálj egy olyan modelt építeni ami alul illesztés áldozata lesz, az eredmények hasonlóak kell legyenek a túlilesztésére, mivel nem képpes megtanulni a dolgokat így sok hibát fog véteni.
# 3.   Építs egy olyan modelt ami előidézi a túlilesztést másabbat a megadottól. Ha megépítetted és sikerült válaszolj egy olyan kérdésre, hogy hogyan történhetett ez?
